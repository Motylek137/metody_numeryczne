# %% [markdown]
# # <center>Laboratorium 2<br>Metody Numeryczne</center>

# %% [markdown]
# Biblioteki niezbędne do wykonania zadania:

# %%
import main

import numpy as np
import scipy
import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# ***Zadanie 1.***
# Zdefiniuj w notatniku funkcję $f(x)= x^{3} - 3x$ i sporządź jej wykres dla argumentów z przedziału:
# 1. $x\in<-1,1>$
# 2. $x\in<-5,5>$
# 3. $x\in<0,5>$
#
# ***Wskazówki***
# Jako argumentu funkcji można użyć numpy array.
#
# Do wizualizacji wyników w Pythonie używa się pakietu [Matplotlib](https://matplotlib.org/). Działanie tego pakietu prezentuje przykład:

# %%
def f(x):
    return x ** 3 - 3 * x

# %%
#1
x1 = np.linspace(-1, 1)
plt.plot(x1, f(x1))
plt.title("Wykres dla przedzialu: <-1 , 1>")
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.show()

# %%
#2
x2 = np.linspace(-5,5)
plt.plot(x2, f(x2))
plt.title("Wykres dla przedzialu: <-5 , 5>")
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.grid()
plt.show()

# %%
#3
x3 = np.linspace(0, 5)
plt.plot(x3, f(x3))
plt.title("Wykres dla przedzialu: <0 , 5>")
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.show()

# %%
x = np.linspace(-10,10)
# inicjalizacja wektora f(x) = sin(x)
y = np.sin(x)
plt.plot(x, y, label ='sin(x)')
plt.show()

# %% [markdown]
# Wspierając się dokumentacją [Matplotlib](https://matplotlib.org/) dodaj do wykresu etykiety osi, tytuł, grida i legendę.

# %% [markdown]
# ***Zadanie 2.***
# Dla funkcji z zadania pierwszego używając wektora $x \in <-10,10>$ wyrysuj wykres dla argumentów:
# 1. $x\in<-1,1>$
# 2. $x\in<-10,-1>$
# 3. $x\in<1,10>$
#
# Używając do tego funkcji: [ylim](https://matplotlib.org/3.3.1/api/_as_gen/matplotlib.pyplot.ylim.html), [xlim](https://matplotlib.org/3.3.2/api/_as_gen/matplotlib.pyplot.xlim.html), [axis](https://matplotlib.org/3.3.2/api/_as_gen/matplotlib.pyplot.axis.html)

# %%
#1
x = np.linspace(-10, 10)
plt.plot(x, f(x))
plt.title("Wykres dla przedzialu: <-1 , 1>")
plt.xlim(-1,1)
plt.ylim(-5,5)
plt.grid()
plt.show()

# %%
#2
plt.plot(x, f(x))
plt.axis([-10, -1, -100, 3])
plt.title("Wykres dla przedzialu: <-10 , -1>")
plt.grid()
plt.show()

# %%
#3
plt.plot(x, f(x))
plt.axis([1, 10, -3, 100])
plt.title("Wykres dla przedzialu: <1 , 10>")
plt.grid()
plt.show()

# %% [markdown]
# ***Zadanie 3.***
# Oblicz ilość ciepła, które wydzieli się podczas hamowania jeżeli opisuje je zależność:
#
# $Q = \cfrac{mv^2}{2}$
#
# jeżeli $m = 2500g$, $v = 60km/h$, wypisz wynik oraz podaj w kilokaloriach i dżulach. Wykreśl wykresy które zobrazują zmianę ilości ciepła w procesie hamowania dla ciała o masie $3000g$ i prędkości $v\in<200,0>km/h$, przedstawiając ciepło hamowania na pierwszym w skali liniowej na drugim w skali logarytmicznej.
#
# ***Wsakzówka:*** Do stworzenia wykresów z osią logarytmiczną skorzystaj z funkcji: [semilogy](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.semilogy.html), [xlim](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.xlim.html?highlight=xlim#matplotlib.pyplot.xlim) i [figure](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.figure.html?highlight=figure#matplotlib.pyplot.figure) z pakietu *Matplotlib*.

# %%
def q(m ,v):
    return m*(v**2)/2

m1 = 2500
m2 = 3000
v1 = 60
v2 = 200

q_J = q(m1/1000, v1/3.6)
q_kcal = q_J / 4186.8
print("Dla m = 2500g oraz v = 60 km/h wynik wynosi: {q_J:0.4} J, {q_kcal:0.4} kcal".format(q_J = q_J, q_kcal = q_kcal))

vec_v = np.linspace(v2, 0)
vec_q = q(m2, vec_v)

plt.plot(vec_v, vec_q)
plt.grid()
plt.title("Wykres w postaci liniowej")
plt.xlim(0, 200)
plt.xlabel("Predkosc")
plt.ylabel("Cieplo")
plt.show()

plt.semilogy(vec_v, vec_q)
plt.grid()
plt.title("Wykres w postaci logrytmicznej")
plt.xlim(0, 200)
plt.xlabel("Predkosc")
plt.ylabel("Cieplo")
# Out:
# Dla m = 2500g oraz v = 60 km/h wynik wynosi: 347.2 J, 0.08293 kcal
# Text(0, 0.5, 'Cieplo')

# %% [markdown]
# ***Zadanie 4.***
# Częstą praktyką szczególnie w dziedzinie analizy danych, statystyce, uczeniu maszynowym, itp. jest tworzenie na podstawie biblioteki [Matplotlib](https://matplotlib.org/) własnych szablonów wykresów stworzonych na podstawie funkcji. Najprostszy przykład to przeładowanie funkcji plot tak by wykres miał czerwony kolor:

# %%
def my_plot(x,y,xlabel,ylabel,title,label):
    if x.shape != y.shape or  min(x.shape)==0:
        return None
    fig, ax = plt.subplots()
    ax.plot(x, y, 'r', label=label)
    ax.set(xlabel=xlabel, ylabel=ylabel, title=title)
    ax.legend()
    return fig

x = np.linspace(-10,10)
# inicjalizacja wektora f(x) = sin(x)
y = np.sin(x)
my_plot(x,y,'x','y','Funkcja sin', 'sin(x)')

# %% [markdown]
# Zaimplementuj funkcję *compare\_plot* w taki sposób by na jednym wykresie wyrysowane były dwie funkcje typu [plot](https://matplotlib.org/3.3.1/api/_as_gen/matplotlib.pyplot.plot.html#matplotlib.pyplot.plot). Pierwsza ma rysować się w kolorze niebieski i grubość lini ma wynosić 4, druga natomiast w kolorze czerwonym o grubości lini 2. Domyślnie ma być dodawana legenda. Dodatkowo użytkownik ma mieć możliwość ustawienia parametrów:
# - x1 - wektor wartości osi x dla pierwszego wykresu,
# - y1 - wektor wartości osi y dla pierwszego wykresu,
# - x2 - wektor wartości osi x dla drugiego wykresu,
# - y2 - wektor wartości osi x dla drugiego wykresu,
# - xlabel - opis osi x,
# - ylabel - opis osi y,
# - title - tytuł wykresu ,
# - label1 - nazwa serii z pierwszego wykresu,
# - label2 - nazwa serii z drugiego wykresu.
#
# Jeżeli nie da się wyrysować danych należy zwrócić wartość None.

# %% [markdown]
# ** Zadanie 5 **
# Za pomocą funkcji *compare\_plot* rozwiąż graficznie równanie: $f(x) = g(x)$, gdzie:
# $f(x) = x+2$
# $g(x) = x^2 -2sin(x) + 3$

# %%
def compare_plot(x1:np.ndarray,y1:np.ndarray,x2:np.ndarray,y2:np.ndarray,
                 xlabel: str,ylabel:str,title:str,label1:str,label2:str):
    
    if (x1.shape != y1.shape) or (x2.shape != y2.shape):
        return None
    else:
        fig, ax = plt.subplots()
        ax.plot(x1, y1, 'b', linewidth = 4, label=label1)
        ax.plot(x2, y2, 'r', linewidth = 2, label=label2)
        ax.set(xlabel=xlabel, ylabel=ylabel, title=title)
        ax.legend()
        return fig

x1 = np.linspace(-5, 5)
y1 = x1 + 2
x2 = np.linspace(-5, 5)
y2 = x1**2 - 2 * np.sin(x2) + 3

xlabel = 'Os x'
ylabel = 'Os y'
title = 'Porownanie dwoch wykresow'
label1 = 'y = x + 2'
label2 = 'y = x^2 - 2sin(x) +3'

compare_plot(x1, y1, x2, y2, xlabel, ylabel, title, label1, label2)

# %% [markdown]
# ***Zadanie 6.***
# Innym przydatnym sposobem prezentowania wykresów jest [subplot](https://matplotlib.org/3.3.2/api/_as_gen/matplotlib.pyplot.subplot.html), czyli wyrysowanie obok siebie kilku wykresów. Zaimplementuj funkcję parallel_plot tak by obok siebie wyrysowane zostały dwa standardowe ploty i użytkownik mógł podać parametry:
# - x1 - wektor wartości osi x dla pierwszego wykresu,
# - y1 - wektor wartości osi y dla pierwszego wykresu,
# - x2 - wektor wartości osi x dla drugiego wykresu,
# - y2 - wektor wartości osi x dla drugiego wykresu,
# - x1label - opis osi x dla pierwszego wykresu,
# - y1label - opis osi y dla pierwszego wykresu,
# - x2label - opis osi x dla drugiego wykresu,
# - y2label - opis osi y dla drugiego wykresu,
# - title - tytuł wykresu,
# - orientation - parametr przyjmujący wartość '-' jeżeli subplot ma posiadać dwa wiersze albo '|' jeżeli ma posiadać dwie kolumny.
#
# Jeżeli nie da się wyrysować danych należy zwrócić wartość None.

# %%
def parallel_plot(x1:np.ndarray,y1:np.ndarray,x2:np.ndarray,y2:np.ndarray,
                  x1label:str,y1label:str,x2label:str,y2label:str,title:str,orientation:str):
    if (x1.shape != y1.shape) or (x2.shape != y2.shape) or min(x1.shape) == 0 or min(x2.shape) == 0:
        return None
    if orientation == '-':
        fig, (ax1, ax2) = plt.subplots(2,1)
    elif orientation == '|':
        fig, (ax1, ax2) = plt.subplots(1,2)
    ax1.plot(x1, y1)
    ax1.set(xlabel=x1label, ylabel=y1label)
    ax2.plot(x2, y2)
    ax2.set(xlabel=x2label, ylabel=y2label)
    fig.suptitle(title)
    return fig

x1 = np.linspace(-5, 5)
y1 = x1 + 2
x2 = np.linspace(-5, 5)
y2 = x1**2 - 2 * np.sin(x2) + 3
x1label = 'Os x'
y1label = 'Os y'
title = 'Dwa wykresy w dwoch oknach'
x2label = 'Os x'
y2label = 'Os y'
orientation = '-'

parallel_plot(x1, y1, x2, y2, x1label, y1label, x2label, y2label, title, orientation)

# %% [markdown]
# ***Zadanie 7.***
# Za pomocą funkcji *parallel\_plot*  i przedstaw na jednym z nich [Spirale logarytmiczną](https://pl.wikipedia.org/wiki/Spirala_logarytmiczna) w szerokim przedziale, a w drugim w okolicy zera.

# %%
a1=100 #odpowiada za wielkosc spirali
b1=0.3 #decyduje jak "szybko" i w którą strone skręca spirala
a2=0.1
b2=0.3
fi = np.linspace(0, 4*np.pi, 100)
r1 = a1 * np.exp(b1 * fi)
x1 = r1 * np.cos(fi)
y1 = r1 * np.sin(fi)
r2 = a2 * np.exp(b2 * fi)
x2 = r2 * np.cos(fi)
y2 = r2 * np.sin(fi)

parallel_plot(x1, y1, x2, y2, 'x', 'y', 'x', 'y', 'Spirala logarytmiczna', '|')

# %% [markdown]
# ***Zadanie 8.***
# Zaimplementuj funkcję *log\_plot* która będzie tworzyć wykres w skalach logaritmicznych. Skale logarytmiczne mają być ustawione zgodnie z parameterem *log\_axis* gdzie wartość:
# - 'x' oznacza skale logarytmiczną na osi x,
# - 'y' oznacza skale logarytmiczną na osi y,
# - 'xy' oznacza skale logarytmiczną na obu osiach.
#
# Dodatkowo użytkownik ma mieć możliwość ustawienia parametrów:
# - x - wektor wartości osi x,
# - y - wektor wartości osi y,
# - xlabel - opis osi x,
# - ylabel - opis osi y,
# - title - tytuł wykresu.

# %%
def log_plot(x:np.ndarray,y:np.ndarray,xlabel:str,ylabel:str,title:str,log_axis:str): 
    if x.shape != y.shape:
        return None
    fig, ax = plt.subplots() 
    ax.plot(x, y)
    ax.set(xlabel=xlabel, ylabel=ylabel, title=title)
    if log_axis == 'x':
        ax.set_xscale('log')
    elif log_axis == 'y':
        ax.set_yscale('log')
    else:
        ax.set_xscale('log')
        ax.set_yscale('log')
    return fig

# %%
x = np.linspace(-1000, 1000)
y = x + 2
xlabel = ''
ylabel = ''
title = "Wykres w skalach logarytmicznych"
log_plot(x,y,xlabel,ylabel,title,'y')

# %% [markdown]
# **Zadanie 9.**
# Przy pomocy funkcji *log\_plot* przedstaw różne warianty funkcji z zadania 3.

# %%
log_plot(vec_v, vec_q, "Predkosc", "Cieplo", "os x w skali logarytmicznej", 'x')
log_plot(vec_v, vec_q, "Predkosc", "Cieplo", "os y w skali logarytmicznej", 'y')
log_plot(vec_v, vec_q, "Predkosc", "Cieplo", "os x i y w skali logarytmicznej", 'xy')

# %% [markdown]
# WNIOSKI:
# Na tym laboratorium poznałem bardzo przydatną bibliotekę matplotlib. Biblioteka ta pozwala na rysowanie funkcji w pythonie, jest ona przyjemna i nieskomplikowana w użytkowaniu.
# W tym bloku dowiedziałem się jak korzystać z poszczególnych funkcji tej biblioteki, dzięki zadaniom związanych z implementacją własnych funkcji (compare_plot, parallel_plot, log_plot) nauczyłem się tworzyć własne szablony funkcji, dowiedziałem się także, jak opisać wykres dodająć tytuł, podpisy osi, legędę, siatke itp.
# Niestety wystąpił jeden błąd, którego jeszcze nie udało mi się rozwiązać, mianowicie chodzi o definicje funkcji w pliku main.py: Funckje nie chcą się uruchamiać w sprawozdaniu. Po dodaniu kodu do spawozdania funkcje zwracają wykresy, więc zakładam, że wszystko zostało przeze mnie dobrze zaimplementowane. Testy również wszystkie przeszły pomyślnie(funkcje w pliku main.py jest identyczny jak w sprawozdaniu).
# Mimo tego uznaje to laboratorium za bardzo pomocne, ponieważ dzięki niemu nauczyłem się sporo nowych rzeczy, jak i mogłem poprawiać swoje umiejętności programowania w języku python.

# %% [markdown]
# Materiały uzupełniające:
# - [Scipy Lecture Notes](http://www.scipy-lectures.org/index.html)
# - [NumPy for Matlab users](https://docs.scipy.org/doc/numpy/user/numpy-for-matlab-users.html#numpy-for-matlab-users)
# - [Python Tutorial - W3Schools](https://www.w3schools.com/python/default.asp)
# - [NumPy](https://www.numpy.org)
# - [Matplotlib](https://matplotlib.org/)
# - [Anaconda](https://www.anaconda.com/)
# - [Learn Python for Data Science](https://www.datacamp.com/learn-python-with-anaconda?utm_source=Anaconda_download&utm_campaign=datacamp_training&utm_medium=banner)
# - [Learn Python](https://www.learnpython.org/)
# - [Wujek Google](https://google.pl) i [Ciocia Wikipedia](https://pl.wikipedia.org/wiki/Wikipedia:Strona_g%C5%82%C3%B3wna)
